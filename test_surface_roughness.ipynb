# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from rfp2 import *

# %%
folder_name = 'test_long_surface'
result = []
extrac = []
nRound=10

for iteration in [0]:
    filename = 'n' + str(iteration) + '_recirc' + '.txt'
    power_list = []
    with open(folder_name + '/' + filename) as f:
        lines = f.readlines()

    round_list = []
    power_list = []
    for k in range(1,len(lines)):
        temp = lines[ k].split(' ')
        nround = int(temp[0])
        power = float(temp[6])
        round_list.append(nround)
        power_list.append(power)
    power_list = [x for _, x in sorted(zip(round_list, power_list))]
    result.extend(power_list)

plt.figure(figsize = (15,7))
plt.plot(result)
plt.xlabel('Passes', fontsize = 15)
plt.ylabel('beam center (\mu m)', fontsize = 15)
# Out:
# Text(0, 0.5, 'beam center (\\mu m)')

# %%
fld = read_dfl(filename = 'test_long_surface/test.dfl', ncar=181)
plot_fld_marginalize_t(fld = fld, dgrid = 540e-6, dt=1e-6/3e8)
# Out:
# 3.471496343612671 seconds to read in fld array (268509156,)
# read 8196 slices
# 0.0006272792816162109 seconds to reshape fld array (8196, 181, 181)
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# norm = 179777400486.92953     energy = 599.3  uJ    x , y  mean = 26.9 um , 15.8 um      x , y  rms = 85.3 um , 121.1 um     wx , wy = 170.6 um , 242.2 um     x , y  fwhm = 93.1 um , 131.9 um
